# %% [markdown]
# # Astropy Workshop
#
# ## AAVSO 112th Annual Meeting, Boston, MA

# %% [markdown]
# ## Acknowledgements
#
# This workshop is funded by Astropy with support from the Gordon and Betty Moore Foundation.
#
# ![Astropy logo](https://www.astropy.org/images/astropy_project_logo.svg)
#
# ![Moore Foundation logo](attachment:7b32a95f-e4fc-49cd-a01a-3d8c0441867e.png)

# %% [markdown]
# ## Code of Conduct
#
# We'll follow the [Astropy code of conduct](https://www.astropy.org/code_of_conduct.html) during the workkshop, the essence of which is below:
#
# > The community of participants in open source Astronomy projects is made up of members from around the globe with a diverse set of skills, personalities, and experiences. It is through these differences that our community experiences success and continued growth. We expect everyone in our community to follow these guidelines when interacting with others both inside and outside of our community. **Our goal is to keep ours a positive, inclusive, successful, and growing community.**

# %% [markdown]
# ## Introduction to Jupyter Lab
#
# Every activity in this workshop is in a Jupyter notebook. Some cells, like this one, have text.
#
# Double-click on the cell if you want to edit it.
#
# **As an exercise, fill in your name below:**
#
# Your name  👈👈👈

# %% [markdown]
# ### Some cells, like the one below, have code
#
# Click in the cell below, then hold down the Shift key and press Enter to run the cell 👇👇👇

# %%
print("Hello!")

# %% [markdown]
# ### Most notebooks will have an `import` cell like the one below
#
# These statements tell python to load the packages we will use in the notebook.
#
# Click in the cell, then do the Shift-Enter thing to run the cell.

# %%
from astropy.table import Table

import numpy as np

# %% [markdown]
# Nothing much will happen after running imports. That is normal.

# %% [markdown]
# ### How to tell when your computer is working on a calculation
#
# Some of the things we will do will take some time to complete. You can tell that a cell is still running in two ways:
#
# + The brackets next to the cell have a star in it: `[*]`
# + In the upper right of the nbm, near where it says something like "Python 3 (ipykernel)" the circle will be filled in.
#
# To see that in action, run the cell below. (Remember, Shift-Enter to run a cell)

# %%
from time import sleep

sleep(5) ## do nothing for five seconds

# %% [markdown]
# ## You can close the file browser on the left
#
# Click the folder icon to close or open the file browser. It is handy to close it sometimes to have more screen space.
